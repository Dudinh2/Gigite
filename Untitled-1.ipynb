# %%
import pandas as pd

data  = {
    'nome': ['Ana','Bruno','Carlos','Diana'],
    'idade': [28,34,45,22],
    'Cidade':['São Paulo', 'Rio','Bahia','Curitiba']
}

df = pd.DataFrame(data)

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import openpyxl
caminho = (r'C:\Users\maria-eduarda_rosa\Downloads\Pasta1.xlsx')

df2 = pd.read_excel(caminho, engine = 'openpyxl')

# %%
df2
# Out:
#      Nome  Idade     Cidade
# 0     Ana     28  São Paulo
# 1   Bruno     34        Rio
# 2  Carlos     45      Bahia
# 3   Diana     22   Curitiba

# %%
import openpyxl

trabalho = (r'C:\Users\maria-eduarda_rosa\Downloads\DEMANDAS DUDA.xlsx')
df2 = pd.read_excel(trabalho, engine = 'openpyxl' )

# %%
df2
# Out:
#    \n Tarefas      Unnamed: 1                         Unnamed: 2  \
# 0         NaN             NaN                                NaN
# 1           ✓   DIA DA SEMANA                             Tarefa
# 2       False  SEGUNDA- FEIRA               ATUALIZAR DASH DE PM
# 3       False  SEGUNDA- FEIRA                          OLHAR EWO
# 4       False  SEGUNDA- FEIRA                OLHAR OS 5S DA ÁREA
# 5       False  SEGUNDA- FEIRA  ATIVIDADES PM DO FINAL DE SEMANA
# 6       False  SEGUNDA- FEIRA                                NaN
# 7       False  SEGUNDA- FEIRA                                NaN
# 8       False  SEGUNDA- FEIRA                                NaN
# 9         NaN             NaN                                NaN
# 10      False     TERÇA-FEIRA                           PROJETOS
# 11      False     TERÇA-FEIRA                          SEGURANÇA
# 12      False     TERÇA-FEIRA                        GS3-EVENTOS
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_frutas = df_frutas['Fruta     Cor        Gosto      Formato    Casca'].str.split(expand=True)
#
# NameError: name 'df_frutas' is not defined
